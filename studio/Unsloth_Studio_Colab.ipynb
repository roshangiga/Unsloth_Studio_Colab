# %% [markdown]
# <a href="https://colab.research.google.com/github/roshangiga/Unsloth_Studio_Colab/blob/main/studio/Unsloth_Studio_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# To run this, press "*Runtime*" and press "*Run all*" on a **free** Tesla T4 Google Colab instance!
# <div class="align-center">
# <a href="https://unsloth.ai/"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
# <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord button.png" width="145"></a>
# <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a> Join Discord if you need help + ⭐ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐
# </div>
#
# To install Unsloth Studio on your local device, follow [our guide](https://unsloth.ai/docs/new/unsloth-studio/install). Unsloth Studio is licensed [AGPL-3.0](https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0).
#
# ### Unsloth Studio
#
# Train and run open models with [**Unsloth Studio**](https://unsloth.ai/docs/new/unsloth-studio/start). NEW! Installation should now only take 2 mins!
#
#
# We are actively working on making Unsloth Studio install on Colab T4 GPUs faster.
#
# [Features](https://unsloth.ai/docs/new/unsloth-studio#features) • [Quickstart](https://unsloth.ai/docs/new/unsloth-studio/start) • [Data Recipes](https://unsloth.ai/docs/new/unsloth-studio/data-recipe) • [Studio Chat](https://unsloth.ai/docs/new/unsloth-studio/chat) • [Export](https://unsloth.ai/docs/new/unsloth-studio/export)

# %% [markdown]
# <p align="left"><img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/studio%20github%20landscape%20colab%20display.png" width="600"></p>

# %% [markdown]
# ### Setup: Clone repo and run setup

# %%
# !git clone --depth 1 --branch main https://github.com/unslothai/unsloth.git
# %cd /content/unsloth
# !chmod +x studio/setup.sh && ./studio/setup.sh --local
# Out:
# Cloning into 'unsloth'...
# remote: Enumerating objects: 1580, done.
# remote: Counting objects: 100% (1580/1580), done.
# remote: Compressing objects: 100% (1382/1382), done.
# remote: Total 1580 (delta 196), reused 1072 (delta 174), pack-reused 0 (from 0)
# Receiving objects: 100% (1580/1580), 37.10 MiB | 18.63 MiB/s, done.
# Resolving deltas: 100% (196/196), done.
# /content/unsloth
#
#   🦥 Unsloth Studio Setup
#   ────────────────────────────────────────────────────
#                  local mode: overlaying /content/unsloth (editable) + unsloth-zoo from git main
#                  upgrading npm...
#   node           v20.19.0 | npm 11.16.0
#                  installing bun...
#                  bun installed (1.3.14)
#                  building frontend...
#                  using bun for package install (faster)
#   frontend       built
#                  Colab detected, installing Studio backend dependencies...
#   python         backend deps installed into system Python
#                  continuing to llama.cpp install for GGUF inference support
#   deps           [==------------------]  2/14  base packages         deps           overlaying local repo (editable): /content/unsloth
#   deps           overlaying unsloth-zoo from git main
#   deps           [====================] 14/14  ROCm torch (final)
#   deps           installed
#   transformers   5.3.0 pre-installed
#   transformers   5.5.0 pre-installed
#   gpu            NVIDIA GPU detected
#                  installing prebuilt llama.cpp...
#   llama.cpp      prebuilt installed and validated
#                  installed release: unslothai/llama.cpp@b9334
#
#   ────────────────────────────────────────────────────
#   Unsloth Studio Setup Complete
#   ────────────────────────────────────────────────────
#                  from colab import start
#                  start()

# %% [markdown]
# ### Start Unsloth Studio

# %%
import sys
sys.path.insert(0, "/content/unsloth/studio/backend")
from colab import start
start()
# Out:
# 2026-06-01 21:11:57 [info     ] 🦥 Starting Unsloth Studio...
# 2026-06-01 21:11:57 [info     ]    Loading backend...
# 2026-06-01 21:11:57 [info     ]    Starting server...
# INFO:     Started server process [17594]
# INFO:     Waiting for application startup.
# Hardware detected: CUDA -- Tesla T4
# INFO:     Application startup complete.
# INFO:     Unsloth Studio running on http://34.87.83.57:8888 (To stop: press Ctrl+C -- on macOS, Control+C not Command+C)
# ============================================================
# DEFAULT ADMIN ACCOUNT CREATED
#     username: unsloth
#     password saved to: /root/.unsloth/studio/auth/.bootstrap_password
#     Open the Studio UI to sign in and change it.
# ============================================================
#
# {"timestamp": "2026-06-01T21:12:07.241819Z", "level": "info", "event": "   Server started on port 8888!"}
# {"timestamp": "2026-06-01T21:12:07.277633Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.09}
# {"timestamp": "2026-06-01T21:12:09.366000Z", "level": "info", "event": "Pre-caching helper GGUF: unsloth/gemma-4-E2B-it-GGUF/gemma-4-E2B-it-UD-Q4_K_XL.gguf"}
# {"timestamp": "2026-06-01T21:12:11.913785Z", "level": "info", "event": "\ud83c\udf10 Unsloth Studio URL: https://8888-gpu-t4-s-kkb-ass1c0-2fups7e2cntfr-c.asia-southeast1-0.prod.colab.dev"}
# <div style="font-family:system-ui,-apple-system,sans-serif;margin:8px 0;
#             border-radius:12px;overflow:hidden;box-shadow:0 2px 16px rgba(0,0,0,0.18);">
#   <div style="display:flex;align-items:center;gap:10px;padding:10px 16px;background:#000;">
#     <img src="https://github.com/unslothai/unsloth/raw/main/studio/frontend/public/unsloth-gem.png"
#          height="26" style="display:block;">
#     <span style="color:#fff;font-weight:700;font-size:15px;letter-spacing:-0.2px;">Unsloth Studio</span>
#     <span style="margin-left:auto;color:#666;font-size:11px;font-family:monospace;">https://8888-gpu-...</span>
#   </div>
#   <iframe
#     id="unsloth-studio-8888"
#     src="https://8888-gpu-t4-s-kkb-ass1c0-2fups7e2cntfr-c.asia-southeast1-0.prod.colab.dev"
#     style="width:100%;height:82vh;min-height:600px;max-height:1100px;border:none;display:block;box-sizing:border-box;"
#     allow="clipboard-read; clipboard-write"
#   ></iframe>
# </div>
# {"timestamp": "2026-06-01T21:12:12.911655Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 71.55}
# {"timestamp": "2026-06-01T21:12:18.986380Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.39}
# {"timestamp": "2026-06-01T21:12:19.570596Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 20.46}
# {"timestamp": "2026-06-01T21:12:20.139228Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 13.52}
# {"timestamp": "2026-06-01T21:12:22.380940Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.8}
# {"timestamp": "2026-06-01T21:12:24.056074Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.66}
# {"timestamp": "2026-06-01T21:12:28.860791Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 1.22}
# {"timestamp": "2026-06-01T21:12:29.410055Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.12}
# {"timestamp": "2026-06-01T21:12:29.957451Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.94}
# {"timestamp": "2026-06-01T21:12:30.819596Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.33}
# {"timestamp": "2026-06-01T21:12:34.632111Z", "level": "info", "event": "Helper GGUF cached: 1 file(s)"}
# {"timestamp": "2026-06-01T21:12:43.046673Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/login", "status_code": 200, "process_time_ms": 81.72}
# {"timestamp": "2026-06-01T21:12:43.772870Z", "level": "info", "event": "request_completed", "method": "POST", "path": "/api/auth/change-password", "status_code": 200, "process_time_ms": 163.16}
# {"timestamp": "2026-06-01T21:12:44.356544Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 2.71}
# {"timestamp": "2026-06-01T21:12:44.367616Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.24}
# {"timestamp": "2026-06-01T21:12:44.391302Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.17}
# {"timestamp": "2026-06-01T21:12:44.900583Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.62}
# {"timestamp": "2026-06-01T21:12:44.958035Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.17}
# {"timestamp": "2026-06-01T21:12:45.434749Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.74}
# {"timestamp": "2026-06-01T21:12:45.976165Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.85}
# {"timestamp": "2026-06-01T21:12:46.526438Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 3.79}
# {"timestamp": "2026-06-01T21:12:46.533568Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 2.5}
# {"timestamp": "2026-06-01T21:12:46.539973Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.49}
# {"timestamp": "2026-06-01T21:12:47.080635Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.76}
# {"timestamp": "2026-06-01T21:12:47.090307Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 1.87}
# {"timestamp": "2026-06-01T21:12:47.618605Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 1.76}
# {"timestamp": "2026-06-01T21:12:47.691337Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/mcp/servers/", "status_code": 200, "process_time_ms": 12.64}
# {"timestamp": "2026-06-01T21:12:47.704287Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/settings", "status_code": 200, "process_time_ms": 10.04}
# {"timestamp": "2026-06-01T21:12:47.705051Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/local", "status_code": 200, "process_time_ms": 10.65}
# {"timestamp": "2026-06-01T21:12:47.711669Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/projects", "status_code": 200, "process_time_ms": 3.44}
# {"timestamp": "2026-06-01T21:12:47.736116Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 1.8}
# {"timestamp": "2026-06-01T21:12:47.992255Z", "level": "info", "event": "InferenceOrchestrator initialized (subprocess mode)"}
# {"timestamp": "2026-06-01T21:12:48.311699Z", "level": "info", "event": "Top GGUF models: ['unsloth/Qwen3-Coder-Next-GGUF', 'unsloth/gemma-4-26B-A4B-it-GGUF', 'unsloth/Qwen3.6-35B-A3B-GGUF', 'unsloth/Qwen3.6-27B-GGUF', 'unsloth/gemma-4-E2B-it-GGUF', 'unsloth/gemma-4-E4B-it-GGUF', 'unsloth/Qwen3.5-9B-GGUF', 'unsloth/Qwen3.6-27B-MTP-GGUF', 'unsloth/Qwen3.6-35B-A3B-MTP-GGUF', 'unsloth/gemma-4-31B-it-GGUF', 'unsloth/Qwen3.5-4B-GGUF', 'unsloth/Qwen3-30B-A3B-Instruct-2507-GGUF', 'unsloth/Qwen3-VL-2B-Instruct-GGUF', 'unsloth/Qwen3.5-0.8B-GGUF', 'unsloth/Kimi-K2.6-GGUF', 'unsloth/LTX-2.3-GGUF', 'unsloth/Qwen3.5-35B-A3B-GGUF', 'unsloth/gpt-oss-120b-GGUF', 'unsloth/GLM-4.7-Flash-GGUF', 'unsloth/gpt-oss-20b-GGUF', 'unsloth/Qwen3-Coder-30B-A3B-Instruct-GGUF', 'unsloth/Qwen3.5-2B-GGUF', 'unsloth/Qwen3.5-27B-GGUF', 'unsloth/Qwen2.5-VL-7B-Instruct-GGUF', 'unsloth/Qwen-Image-Edit-2511-GGUF', 'unsloth/FLUX.2-klein-4B-GGUF', 'unsloth/Qwen3.5-9B-MTP-GGUF', 'unsloth/gemma-3-12b-it-GGUF', 'unsloth/Qwen3.5-122B-A10B-GGUF', 'unsloth/GLM-5.1-GGUF', 'unsloth/FLUX.2-klein-9B-GGUF', 'unsloth/gemma-3-270m-it-GGUF', 'unsloth/DeepSeek-R1-Distill-Qwen-14B-GGUF', 'unsloth/Devstral-Small-2505-GGUF']"}
# {"timestamp": "2026-06-01T21:12:48.314331Z", "level": "info", "event": "Top hub models: ['unsloth/gemma-4-E4B-it', 'unsloth/Qwen3-4B', 'unsloth/gemma-4-31B-it-unsloth-bnb-4bit', 'unsloth/Qwen3.6-27B-NVFP4', 'unsloth/GLM-4.7-Flash', 'unsloth/Llama-3.2-1B-Instruct', 'unsloth/mistral-7b-v0.3-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-bnb-4bit', 'unsloth/gemma-3n-E4B-it', 'unsloth/Qwen2.5-7B-Instruct', 'unsloth/Meta-Llama-3.1-8B-Instruct', 'unsloth/gemma-4-E4B-it-unsloth-bnb-4bit', 'unsloth/gemma-3-4b-it-bnb-4bit', 'unsloth/Qwen3-14B-unsloth-bnb-4bit', 'unsloth/Qwen3-0.6B', 'unsloth/Llama-3.1-8B-Instruct', 'unsloth/Qwen3.6-35B-A3B-NVFP4', 'unsloth/Qwen2.5-3B-Instruct-unsloth-bnb-4bit', 'unsloth/Qwen3-4B-unsloth-bnb-4bit', 'unsloth/Nemotron-3-Nano-30B-A3B', 'unsloth/Qwen3.5-4B', 'unsloth/Qwen3-4B-Instruct-2507-unsloth-bnb-4bit', 'unsloth/Qwen3.5-9B', 'unsloth/gemma-4-E2B-it-unsloth-bnb-4bit', 'unsloth/Qwen2.5-7B-Instruct-unsloth-bnb-4bit', 'unsloth/Llama-3.2-3B-Instruct', 'unsloth/Qwen2.5-Coder-7B-Instruct-bnb-4bit', 'unsloth/Meta-Llama-3.1-8B-Instruct-bnb-4bit', 'unsloth/mistral-7b-instruct-v0.3-bnb-4bit', 'unsloth/Qwen3-0.6B-unsloth-bnb-4bit', 'unsloth/Qwen3-8B-unsloth-bnb-4bit', 'unsloth/gemma-3-4b-it', 'unsloth/Qwen3.5-4B-Base', 'unsloth/Qwen3.6-35B-A3B-UD-MLX-4bit', 'unsloth/Qwen2.5-3B-Instruct', 'unsloth/Qwen3.5-2B', 'unsloth/gemma-4-26B-A4B-it', 'unsloth/llama-3-8b-Instruct-bnb-4bit', 'unsloth/gpt-oss-20b-unsloth-bnb-4bit', 'unsloth/gpt-oss-120b-BF16']"}
# {"timestamp": "2026-06-01T21:12:48.325369Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/list", "status_code": 200, "process_time_ms": 335.34}
# {"timestamp": "2026-06-01T21:12:48.341325Z", "level": "info", "event": "Found 0 trained models in /root/.unsloth/studio/outputs"}
# {"timestamp": "2026-06-01T21:12:48.342996Z", "level": "info", "event": "Found 0 exported models in /root/.unsloth/studio/exports"}
# {"timestamp": "2026-06-01T21:12:48.348804Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/inference/status", "status_code": 200, "process_time_ms": 20.78}
# {"timestamp": "2026-06-01T21:12:48.349376Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/models/loras", "status_code": 200, "process_time_ms": 21.29}
# {"timestamp": "2026-06-01T21:12:48.350940Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/mcp/servers/", "status_code": 200, "process_time_ms": 22.74}
# {"timestamp": "2026-06-01T21:12:51.667013Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/studio/update-status", "status_code": 200, "process_time_ms": 128.75}
# {"timestamp": "2026-06-01T21:13:27.515073Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/mcp/servers/", "status_code": 200, "process_time_ms": 2.23}
# {"timestamp": "2026-06-01T21:13:28.081225Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/chat/threads", "status_code": 200, "process_time_ms": 2.26}
# ==========================={"timestamp": "2026-06-01T23:31:22.831257Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/", "status_code": 200, "process_time_ms": 1.73}
# {"timestamp": "2026-06-01T23:31:30.531669Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/health", "status_code": 200, "process_time_ms": 0.68}
# {"timestamp": "2026-06-01T23:31:31.063245Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.12}
# {"timestamp": "2026-06-01T23:31:32.726819Z", "level": "info", "event": "request_completed", "method": "GET", "path": "/api/auth/status", "status_code": 200, "process_time_ms": 2.06}

# %% [markdown]
# And we're done! If you have any questions on Unsloth, we have a [Discord](https://discord.gg/unsloth) channel! If you find any bugs or want to keep updated with the latest LLM stuff, or need help, join projects etc, feel free to join our Discord!
#
# Some other resources:
# 1. Looking to use Unsloth locally? Read our [Installation Guide](https://unsloth.ai/docs/get-started/install) for details on installing Unsloth on Windows, Docker, AMD, Intel GPUs.
# 2. Learn how to do Reinforcement Learning with our [RL Guide and notebooks](https://unsloth.ai/docs/get-started/reinforcement-learning-rl-guide).
# 3. Read our guides and notebooks for [Text-to-speech (TTS)](https://unsloth.ai/docs/basics/text-to-speech-tts-fine-tuning) and [vision](https://unsloth.ai/docs/basics/vision-fine-tuning) model support.
# 4. Explore our [LLM Tutorials Directory](https://unsloth.ai/docs/models/tutorials-how-to-fine-tune-and-run-llms) to find dedicated guides for each model.
# 5. Need help with Inference? Read our [Inference & Deployment page](https://unsloth.ai/docs/basics/inference-and-deployment) for details on using vLLM, llama.cpp, Ollama etc.
#
# <div class="align-center">
#   <a href="https://unsloth.ai"><img src="https://github.com/unslothai/unsloth/raw/main/images/unsloth%20new%20logo.png" width="115"></a>
#   <a href="https://discord.gg/unsloth"><img src="https://github.com/unslothai/unsloth/raw/main/images/Discord.png" width="145"></a>
#   <a href="https://unsloth.ai/docs/"><img src="https://github.com/unslothai/unsloth/blob/main/images/documentation%20green%20button.png?raw=true" width="125"></a>
#
#   Join Discord if you need help + ⭐️ <i>Star us on <a href="https://github.com/unslothai/unsloth">Github</a> </i> ⭐️
#
#   <b>This notebook is licensed <a href="https://github.com/unslothai/unsloth/blob/main/studio/LICENSE.AGPL-3.0">AGPL-3.0</a></b>
# </div>
